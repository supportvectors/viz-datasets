# %%
# %run supportvectors-style.ipynb
# Out:
# <!-- Many of the styles here are inspired by:
#     https://towardsdatascience.com/10-practical-tips-you-need-to-know-to-personalize-jupyter-notebook-fbd202777e20
#
#
#     On the author's local machine, these exist in the custom.css file. However, in order to keep uniform look and feel,
#     and at the request of participants, I have added it to this common import-file here.
#
#     -->
#
# <link href="https://fonts.googleapis.com/css?family=Lora:400,700|Montserrat:300" rel="stylesheet">
#
# <link href="https://fonts.googleapis.com/css2?family=Crimson+Pro&family=Literata&display=swap" rel="stylesheet">
# <style>
#
#
# #ipython_notebook::before{
#  content:"Comprehensive Introduction to Data Science";
#         color: white;
#         font-weight: bold;
#         text-transform: uppercase;
#         font-family: 'Lora',serif;
#         font-size:20pt;
#         margin-bottom:15px;
#
# }
# body > #header {
#     background: maroon;
#         opacity: 0.7;
# }
#
#
# .navbar-default .navbar-nav > li > a, #kernel_indicator {
#     color: white;
#     transition: all 0.25s;
#     font-size:12pt;
#     font-family: sans;
#     /*font-weight:bold;*/
# }
# .navbar-default {
#     padding-left:100px;
#     background: none;
#     border: none;
# }
#
#
# body > menubar-container {
#     background-color: wheat;
# }
# #ipython_notebook img{
#     display:block;
#
#     background: url("https://www.supportvectors.com/wp-content/uploads/2016/03/logo-poster-smaller.png") no-repeat;
#     background-size: contain;
#
#     padding-left: 600px;
#     padding-right: 100px;
#
#     -moz-box-sizing: border-box;
#     box-sizing: border-box;
# }
#
#
#
# body {
#  #font-family:  'Literata', serif;
#     font-family:'Lora', san-serif;
#     text-align: justify;
#     font-weight: 400;
#     font-size: 12pt;
# }
#
# iframe{
#     width:100%;
#     min-height:600px;
# }
#
# h1, h2, h3, h4, h5, h6 {
# # font-family: 'Montserrat', sans-serif;
#  font-family:'Lora', serif;
#  font-weight: 200;
#  text-transform: uppercase;
#  color: #EC7063 ;
# }
#
# h2 {
#     color: #000080;
# }
#
# .checkpoint_status, .autosave_status {
#     color:wheat;
# }
#
# #notebook_name {
#     font-weight: 1000;
#     font-size:20pt;
#     text-variant:uppercase;
#     color: wheat;
#     margin-right:20px;
# }
# #notebook_name:hover {
# background-color: salmon;
# }
#
#
# .dataframe { /* dataframe atau table */
#     background: white;
#     box-shadow: 0px 1px 2px #bbb;
# }
# .dataframe thead th, .dataframe tbody td {
#     text-align: center;
#     padding: 1em;
# }
#
# .checkpoint_status, .autosave_status {
#     color:wheat;
# }
#
# .output {
#     align-items: center;
# }
#
# div.cell {
#     transition: all 0.25s;
#     border: none;
#     position: relative;
#     top: 0;
# }
# div.cell.selected, div.cell.selected.jupyter-soft-selected {
#     border: none;
#     background: transparent;
#     box-shadow: 0 6px 18px #aaa;
#     z-index: 10;
#     top: -10px;
# }
# .CodeMirror pre, .CodeMirror-dialog, .CodeMirror-dialog .CodeMirror-search-field, .terminal-app .terminal {
#     font-family: 'Source Code Pro Medium' , serif;
#     font-weight: 500;
#     font-size: 12pt;
# }
#
#
#
# </style>

# %% [markdown]
# # Installation of the visualization libraries
#
# In the course of the workshop, we will need the following libraries for our data visualization needs. Run the below cell to install these.

# %%
from IPython.display import Markdown

libraries = [
    'seaborn',
    'altair',
    'bokeh',
    'plotly',
    'hvplot',
    'folium',
    'geopandas',
    'geemap',
    'ee',
    'shap',
]


for library in libraries:
    message = f'<hr><span style="color: salmon; font-weight: bold; width=1000px">{library.upper()} ' \
    + 'library verification and installation if needed</span> <hr>'
    display (Markdown(message))
    
    # !pip install {library} --upgrade
# Out:
# <hr><span style="color: salmon; font-weight: bold; width=1000px">SEABORN library verification and installation if needed</span> <hr>
# Requirement already satisfied: seaborn in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (0.11.2)
# Requirement already satisfied: numpy>=1.15 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from seaborn) (1.19.5)
# Requirement already satisfied: pandas>=0.23 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from seaborn) (1.3.5)
# Requirement already satisfied: scipy>=1.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from seaborn) (1.7.1)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\tkaya\appdata\roaming\python\python38\site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from matplotlib>=2.2->seaborn) (21.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from matplotlib>=2.2->seaborn) (4.28.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied: six in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from pandas>=0.23->seaborn) (2021.3)
# <hr><span style="color: salmon; font-weight: bold; width=1000px">ALTAIR library verification and installation if needed</span> <hr>
# Requirement already satisfied: altair in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (4.2.0)
# Requirement already satisfied: pandas>=0.18 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from altair) (1.3.5)
# Requirement already satisfied: jinja2 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from altair) (3.0.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from altair) (4.1.2)
# Requirement already satisfied: numpy in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from altair) (1.19.5)
# Requirement already satisfied: entrypoints in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from altair) (0.3)
# Requirement already satisfied: toolz in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from altair) (0.11.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from jsonschema>=3.0->altair) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from jsonschema>=3.0->altair) (21.2.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from pandas>=0.18->altair) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from pandas>=0.18->altair) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.18->altair) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from jinja2->altair) (2.0.1)
# <hr><span style="color: salmon; font-weight: bold; width=1000px">BOKEH library verification and installation if needed</span> <hr>
# Requirement already satisfied: bokeh in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (2.4.2)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from bokeh) (6.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from bokeh) (3.0.2)
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from bokeh) (3.10.0.2)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from bokeh) (1.19.5)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from bokeh) (8.4.0)
# Requirement already satisfied: packaging>=16.8 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from bokeh) (21.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from bokeh) (6.1)
# <hr><span style="color: salmon; font-weight: bold; width=1000px">PLOTLY library verification and installation if needed</span> <hr>
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from Jinja2>=2.9->bokeh) (2.0.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from packaging>=16.8->bokeh) (2.4.7)
# Requirement already satisfied: plotly in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (5.5.0)
# Requirement already satisfied: six in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from plotly) (1.16.0)
# <hr><span style="color: salmon; font-weight: bold; width=1000px">HVPLOT library verification and installation if needed</span> <hr>
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from plotly) (8.0.1)
# Requirement already satisfied: hvplot in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (0.7.3)
# Requirement already satisfied: colorcet>=2 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from hvplot) (3.0.0)
# Requirement already satisfied: pandas in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from hvplot) (1.3.5)
# Requirement already satisfied: holoviews>=1.11.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from hvplot) (1.14.7)
# Requirement already satisfied: numpy>=1.15 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from hvplot) (1.19.5)
# Requirement already satisfied: bokeh>=1.0.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from hvplot) (2.4.2)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from bokeh>=1.0.0->hvplot) (8.4.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from bokeh>=1.0.0->hvplot) (6.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from bokeh>=1.0.0->hvplot) (6.1)
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from bokeh>=1.0.0->hvplot) (3.10.0.2)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from bokeh>=1.0.0->hvplot) (3.0.2)
# Requirement already satisfied: packaging>=16.8 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from bokeh>=1.0.0->hvplot) (21.0)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from colorcet>=2->hvplot) (0.4.8)
# Requirement already satisfied: param>=1.7.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from colorcet>=2->hvplot) (1.12.0)
# Requirement already satisfied: panel>=0.8.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from holoviews>=1.11.0->hvplot) (0.12.6)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from holoviews>=1.11.0->hvplot) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from Jinja2>=2.9->bokeh>=1.0.0->hvplot) (2.0.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from packaging>=16.8->bokeh>=1.0.0->hvplot) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from pandas->hvplot) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from pandas->hvplot) (2021.3)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from panel>=0.8.0->holoviews>=1.11.0->hvplot) (4.62.3)
# Requirement already satisfied: requests in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from panel>=0.8.0->holoviews>=1.11.0->hvplot) (2.27.1)
# Requirement already satisfied: markdown in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from panel>=0.8.0->holoviews>=1.11.0->hvplot) (3.3.6)
# Requirement already satisfied: bleach in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from panel>=0.8.0->holoviews>=1.11.0->hvplot) (4.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from python-dateutil>=2.7.3->pandas->hvplot) (1.16.0)
# Requirement already satisfied: colorama in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from tqdm>=4.48.0->panel>=0.8.0->holoviews>=1.11.0->hvplot) (0.4.4)
# Requirement already satisfied: webencodings in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from bleach->panel>=0.8.0->holoviews>=1.11.0->hvplot) (0.5.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from markdown->panel>=0.8.0->holoviews>=1.11.0->hvplot) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from importlib-metadata>=4.4->markdown->panel>=0.8.0->holoviews>=1.11.0->hvplot) (3.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from requests->panel>=0.8.0->holoviews>=1.11.0->hvplot) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from requests->panel>=0.8.0->holoviews>=1.11.0->hvplot) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from requests->panel>=0.8.0->holoviews>=1.11.0->hvplot) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from requests->panel>=0.8.0->holoviews>=1.11.0->hvplot) (1.26.7)
# <hr><span style="color: salmon; font-weight: bold; width=1000px">FOLIUM library verification and installation if needed</span> <hr>
# Requirement already satisfied: folium in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (0.12.1.post1)
# Requirement already satisfied: branca>=0.3.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from folium) (0.4.2)
# Requirement already satisfied: requests in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from folium) (2.27.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from folium) (3.0.2)
# Requirement already satisfied: numpy in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from folium) (1.19.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from requests->folium) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from requests->folium) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from requests->folium) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from requests->folium) (2.0.7)
# <hr><span style="color: salmon; font-weight: bold; width=1000px">GEOPANDAS library verification and installation if needed</span> <hr>
# Collecting geopandas
#   Using cached geopandas-0.10.2-py2.py3-none-any.whl (1.0 MB)
# Collecting fiona>=1.8
#   Using cached Fiona-1.8.20.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.19.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.18.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.17.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.16.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.15.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.14.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.13.post1.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.13.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.12.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.11.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.10.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.9.post2.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.9.post1.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.9.tar.gz (1.2 MB)
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\tkaya\anaconda3\envs\supportvectors\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\tkaya\\AppData\\Local\\Temp\\pip-install-cvertiew\\fiona_3bd17189332648388ad253fb782027dd\\setup.py'"'"'; __file__='"'"'C:\\Users\\tkaya\\AppData\\Local\\Temp\\pip-install-cvertiew\\fiona_3bd17189332648388ad253fb782027dd\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\tkaya\AppData\Local\Temp\pip-pip-egg-info-72m1whwr'
#          cwd: C:\Users\tkaya\AppData\Local\Temp\pip-install-cvertiew\fiona_3bd17189332648388ad253fb782027dd\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/ec/f7/093890341a7e8fbfcdfa04caf4dfb588ebab32c13ceaa6a3819da79ea106/Fiona-1.8.20.tar.gz#sha256=a70502d2857b82f749c09cb0dea3726787747933a2a1599b5ab787d74e3c143b (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\tkaya\anaconda3\envs\supportvectors\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\tkaya\\AppData\\Local\\Temp\\pip-install-cvertiew\\fiona_6aaedb57529d453a9e4aaeeee5cf4ee4\\setup.py'"'"'; __file__='"'"'C:\\Users\\tkaya\\AppData\\Local\\Temp\\pip-install-cvertiew\\fiona_6aaedb57529d453a9e4aaeeee5cf4ee4\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\tkaya\AppData\Local\Temp\pip-pip-egg-info-sfas0r1u'
#          cwd: C:\Users\tkaya\AppData\Local\Temp\pip-install-cvertiew\fiona_6aaedb57529d453a9e4aaeeee5cf4ee4\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/a0/d9/6042aeb073d11341f7726de0586ff71c13117c34959dcf07bd4ee6d4b93e/Fiona-1.8.19.tar.gz#sha256=b9059e0b29c2e9e6b817e53f941e77e1aca7075f986005d38db307067b60458f (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\tkaya\anaconda3\envs\supportvectors\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\tkaya\\AppData\\Local\\Temp\\pip-install-cvertiew\\fiona_3e1dafaa253947519348802ca84c6e35\\setup.py'"'"'; __file__='"'"'C:\\Users\\tkaya\\AppData\\Local\\Temp\\pip-install-cvertiew\\fiona_3e1dafaa253947519348802ca84c6e35\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\tkaya\AppData\Local\Temp\pip-pip-egg-info-r80jsbqk'
#          cwd: C:\Users\tkaya\AppData\Local\Temp\pip-install-cvertiew\fiona_3e1dafaa253947519348802ca84c6e35\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/9f/e8/401cdaa58d862a25c4b3365acf7d2bd7ac77191e3dc9acdcdac0eff20ff0/Fiona-1.8.18.tar.gz#sha256=b732ece0ff8886a29c439723a3e1fc382718804bb057519d537a81308854967a (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\tkaya\anaconda3\envs\supportvectors\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\tkaya\\AppData\\Local\\Temp\\pip-install-cvertiew\\fiona_171e1bd62fbc41658223a21d1c5c5afb\\setup.py'"'"'; __file__='"'"'C:\\Users\\tkaya\\AppData\\Local\\Temp\\pip-install-cvertiew\\fiona_171e1bd62fbc41658223a21d1c5c5afb\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\tkaya\AppData\Local\Temp\pip-pip-egg-info-w48fn9ea'
#          cwd: C:\Users\tkaya\AppData\Local\Temp\pip-install-cvertiew\fiona_171e1bd62fbc41658223a21d1c5c5afb\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/88/62/69347ba2c41b526e1953c4cb66d51170b2869808863c03af202ba0121670/Fiona-1.8.17.tar.gz#sha256=716201c21246587f374785bec6d6a20a984fe1f6c2b0e83bf15127eb8f724d0c (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\tkaya\anaconda3\envs\supportvectors\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\tkaya\\AppData\\Local\\Temp\\pip-install-cvertiew\\fiona_e5cf16583bde4722b36b0bbf790abd57\\setup.py'"'"'; __file__='"'"'C:\\Users\\tkaya\\AppData\\Local\\Temp\\pip-install-cvertiew\\fiona_e5cf16583bde4722b36b0bbf790abd57\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\tkaya\AppData\Local\Temp\pip-pip-egg-info-j1e4sq_x'
#          cwd: C:\Users\tkaya\AppData\Local\Temp\pip-install-cvertiew\fiona_e5cf16583bde4722b36b0bbf790abd57\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/1e/60/dfc6115a11338d8aa96cacd8c60635223d9c97d61d556c90acc5dfd663fa/Fiona-1.8.16.tar.gz#sha256=fd6dfb65959becc916e9f6928618bfd59c16cdbc413ece0fbac61489cd11255f (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\tkaya\anaconda3\envs\supportvectors\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\tkaya\\AppData\\Local\\Temp\\pip-install-cvertiew\\fiona_59da6f4cd6ef46888447457e40a6232b\\setup.py'"'"'; __file__='"'"'C:\\Users\\tkaya\\AppData\\Local\\Temp\\pip-install-cvertiew\\fiona_59da6f4cd6ef46888447457e40a6232b\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\tkaya\AppData\Local\Temp\pip-pip-egg-info-49n6xa8r'
#          cwd: C:\Users\tkaya\AppData\Local\Temp\pip-install-cvertiew\fiona_59da6f4cd6ef46888447457e40a6232b\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/55/2f/17450ec2c8fcc720a8a3e4d9a383499508475c7cfb90f7eca9fb585ac598/Fiona-1.8.15.tar.gz#sha256=3b1c9b5c834fae2fe947cfaea176db890bc6750d1a6ba9f54d969c19ffcd191e (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\tkaya\anaconda3\envs\supportvectors\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\tkaya\\AppData\\Local\\Temp\\pip-install-cvertiew\\fiona_7f267370f20d4053ac8f4e4a51576ab6\\setup.py'"'"'; __file__='"'"'C:\\Users\\tkaya\\AppData\\Local\\Temp\\pip-install-cvertiew\\fiona_7f267370f20d4053ac8f4e4a51576ab6\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\tkaya\AppData\Local\Temp\pip-pip-egg-info-bsnotwqu'
#          cwd: C:\Users\tkaya\AppData\Local\Temp\pip-install-cvertiew\fiona_7f267370f20d4053ac8f4e4a51576ab6\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/5c/fd/5ec54f2d9b3d5dd23dd443fad5630d6b872e2664814c68b856c47e0d65af/Fiona-1.8.14.tar.gz#sha256=6eac038206c89d2cf5f99ea38b81cc228dc21eac5f47870a9a32d453b0007f4d (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\tkaya\anaconda3\envs\supportvectors\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\tkaya\\AppData\\Local\\Temp\\pip-install-cvertiew\\fiona_e392b87ca59e43cab092d11527b2b15a\\setup.py'"'"'; __file__='"'"'C:\\Users\\tkaya\\AppData\\Local\\Temp\\pip-install-cvertiew\\fiona_e392b87ca59e43cab092d11527b2b15a\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\tkaya\AppData\Local\Temp\pip-pip-egg-info-ckixpxcl'
#          cwd: C:\Users\tkaya\AppData\Local\Temp\pip-install-cvertiew\fiona_e392b87ca59e43cab092d11527b2b15a\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/6d/42/f4a7cac53b28fa70e9a93d0e89a24d33e14826dad6644b699362ad84dde0/Fiona-1.8.13.post1.tar.gz#sha256=1a432bf9fd56f089256c010da009c90d4a795c531a848132c965052185336600 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\tkaya\anaconda3\envs\supportvectors\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\tkaya\\AppData\\Local\\Temp\\pip-install-cvertiew\\fiona_a2c7b177462c4f60b443eed5b01c0a82\\setup.py'"'"'; __file__='"'"'C:\\Users\\tkaya\\AppData\\Local\\Temp\\pip-install-cvertiew\\fiona_a2c7b177462c4f60b443eed5b01c0a82\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\tkaya\AppData\Local\Temp\pip-pip-egg-info-tw5ipf6c'
# <hr><span style="color: salmon; font-weight: bold; width=1000px">GEEMAP library verification and installation if needed</span> <hr>
#   Using cached Fiona-1.8.8.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.7.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.6.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.5.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.4.tar.gz (1.1 MB)
#   Using cached Fiona-1.8.3.tar.gz (1.1 MB)
#   Using cached Fiona-1.8.2.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.1.tar.gz (1.1 MB)
#   Using cached Fiona-1.8.0.tar.gz (1.4 MB)
# Collecting geopandas
#   Using cached geopandas-0.10.1-py2.py3-none-any.whl (1.0 MB)
#   Using cached geopandas-0.10.0-py2.py3-none-any.whl (1.0 MB)
#   Using cached geopandas-0.9.0-py2.py3-none-any.whl (994 kB)
#   Using cached geopandas-0.8.2-py2.py3-none-any.whl (962 kB)
# Collecting fiona
#   Using cached Fiona-1.7.13.tar.gz (731 kB)
# Requirement already satisfied: pandas>=0.23.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from geopandas) (1.3.5)
# Requirement already satisfied: shapely in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from geopandas) (1.8.0)
# Requirement already satisfied: pyproj>=2.2.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from geopandas) (3.3.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from pandas>=0.23.0->geopandas) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from pandas>=0.23.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from pandas>=0.23.0->geopandas) (2021.3)
# Requirement already satisfied: certifi in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from pyproj>=2.2.0->geopandas) (2021.10.8)
# Requirement already satisfied: six>=1.5 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.23.0->geopandas) (1.16.0)
# Requirement already satisfied: cligj>=0.4 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (
0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (228)
# Requirement already satisfied: jupyterlab-server~=2.3 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from jupyterlab>=3->geemap) (2.10.3)
# Requirement already satisfied: jupyter-server~=1.4 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from jupyterlab>=3->geemap) (1.13.3)
# Requirement already satisfied: nbclassic~=0.2 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from jupyterlab>=3->geemap) (0.3.5)
# Requirement already satisfied: packaging in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from jupyterlab>=3->geemap) (21.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (0.9.4)
# Requirement already satisfied: Send2Trash in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (1.8.0)
# Requirement already satisfied: websocket-client in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (1.2.3)
# Requirement already satisfied: nbconvert in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (6.1.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (3.5.0)
# Requirement already satisfied: argon2-cffi in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (20.1.0)
# Requirement already satisfied: prometheus-client in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (0.11.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.4->jupyterlab>=3->geemap) (1.2.0)
# Requirement already satisfied: idna>=2.8 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.4->jupyterlab>=3->geemap) (3.3)
# Requirement already satisfied: babel in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab>=3->geemap) (2.9.1)
# Requirement already satisfied: jsonschema>=3.0.1 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab>=3->geemap) (4.1.2)
# Requirement already satisfied: json5 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab>=3->geemap) (0.9.6)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab>=3->geemap) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab>=3->geemap) (21.2.0)
# Requirement already satisfied: notebook<7 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from nbclassic~=0.2->jupyterlab>=3->geemap) (6.4.3)
# Requirement already satisfied: wcwidth in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=0.1.230->geemap) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from requests->folium>=0.11.0->geemap) (2.0.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from requests->folium>=0.11.0->geemap) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from requests->folium>=0.11.0->geemap) (2021.10.8)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from terminado>=0.8.3->jupyter-server~=1.4->jupyterlab>=3->geemap) (0.5.7)
# Requirement already satisfied: whitebox in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from whiteboxgui>=0.6.0->geemap) (2.0.3)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from argon2-cffi->jupyter-server~=1.4->jupyterlab>=3->geemap) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from cffi>=1.0.0->argon2-cffi->jupyter-server~=1.4->jupyterlab>=3->geemap) (2.20)
# Requirement already satisfied: pytz>=2015.7 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from babel->jupyterlab-server~=2.3->jupyterlab>=3->geemap) (2021.3)
# Requirement already satisfied: ratelim in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from geocoder->geemap) (0.1.6)
# Requirement already satisfied: google-resumable-media>=1.3.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from google-cloud-storage->earthengine-api>=0.1.230->geemap) (2.1.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=1.6.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from google-cloud-storage->earthengine-api>=0.1.230->geemap) (2.2.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from google-resumable-media>=1.3.0->google-cloud-storage->earthengine-api>=0.1.230->geemap) (1.3.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from matplotlib->geemap) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from matplotlib->geemap) (4.28.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from matplotlib->geemap) (0.10.0)
# Requirement already satisfied: defusedxml in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (0.7.1)
# Requirement already satisfied: testpath in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (0.5.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (1.4.3)
# Requirement already satisfied: bleach in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (4.0.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (0.1.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (0.5.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (0.8.4)
# Requirement already satisfied: async-generator in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (1.10)
# Requirement already satisfied: webencodings in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from bleach->nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (0.5.1)
# Requirement already satisfied: pyproj>=2 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from owslib->geemap) (3.3.0)
# Requirement already satisfied: pyyaml in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from owslib->geemap) (6.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from plotly->geemap) (8.0.1)
# Requirement already satisfied: websockets>=9.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from voila->geemap) (10.1)
# Requirement already satisfied: ee in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (0.2)
# Requirement already satisfied: blessings in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from ee) (1.7)
# Requirement already satisfied: six in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from blessings->ee) (1.16.0)
# <hr><span style="color: salmon; font-weight: bold; width=1000px">SHAP library verification and installation if needed</span> <hr>
# Requirement already satisfied: shap in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (0.40.0)
# Requirement already satisfied: cloudpickle in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from shap) (2.0.0)
# Requirement already satisfied: packaging>20.9 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from shap) (21.0)
# Requirement already satisfied: scipy in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from shap) (1.7.1)
# Requirement already satisfied: pandas in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from shap) (1.3.5)
# Requirement already satisfied: numba in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from shap) (0.55.0)
# Requirement already satisfied: tqdm>4.25.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from shap) (4.62.3)
# Requirement already satisfied: scikit-learn in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from shap) (1.0)
# Requirement already satisfied: slicer==0.0.7 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from shap) (0.0.7)
# Requirement already satisfied: numpy in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from shap) (1.19.5)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from packaging>20.9->shap) (2.4.7)
# Requirement already satisfied: colorama in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from tqdm>4.25.0->shap) (0.4.4)
# Requirement already satisfied: setuptools in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from numba->shap) (58.0.4)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from numba->shap) (0.38.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from pandas->shap) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from python-dateutil>=2.7.3->pandas->shap) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from scikit-learn->shap) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\tkaya\anaconda3\envs\supportvectors\lib\site-packages (from scikit-learn->shap) (1.0.1)
